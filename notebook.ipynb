# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# For every column in the data:
#
#     State whether the values match the description given in the table above.
#
#     State the number of missing values in the column.
#
#     Describe what you did to make values match the description if they did not match.

# %% [markdown]
# product_id: The unique identifier. There were no missing values in this column. No changes were made to this column.
#
# category: This column had six unique values as the data description, there were 25 missing values saved as ‘-’. the missing values were replaced with ‘unknown’ as per the data description.
#
# animal: This column had four types which matched those in the description. There were no missing values. No changes were made to this column.
#
# size: This column had three categories as the data description but had inconsistent capitalization. There were no missing values in this column. The inconsistencies were fixed by changing all values in lower case to match the data description.
#
# price: The values in this column were positive values and rounded to two decimal places which is consistent with the description given. There were 150 null values saved as ‘unlisted’ and were replaced with the overall median price which was 28.07 approximately.
#
# sales: The values in this column were all positive values and rounded to two decimal places. There were no missing values. No changes were made in this column.
#
# rating: The values in this column were in the range of 1–10 which matched the description given. There were 150 missing values and they were replaced with 0 as per the data description.
#
# repeated_purchase: All the values in this column were either 1 or 0. There were no missing values in this column. No changes were made to this column.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ## Create a visualization that shows how many products are repeat purchases. Use the
# ## visualization to:
# ##
# ##     a. State which category of the variable repeat purchases has the most observations
# ##     b. Explain whether the observations are balanced across categories of the variable repeat purchases

# %% [markdown]
# There are two categories of repeat purchases. The distribution shows that most customers buy the products repeatedly. The observations are not balanced as 60% of the customers buy the products more than once.
#
#
# ![tt](tt.png)

# %% [markdown]
# ## Task 3

# %% [markdown]
# ## **Describe the distribution of all of the sales. Your answer must include a visualization that shows the distribution.**

# %% [markdown]
# As the marketing team thinks that the distribution of sales of a place will be important, we should look at how the number of sales are distributed.
#
# Looking at all sales, we can see from the graphic below that most places have had lower than 1500 sales. The distribution of the number of sales is right-skewed. There are some places that get more than 1500 sales but this is very uncommon.
#
# When looking for places that have high sales, the team should aim for locations having over 1500 sales, but be aware there may need to work with 1000 sales or more.
#
# ![t2](t2.png)

# %% [markdown]
# ## Task 4

# %% [markdown]
# ## **Describe the relationship between repeat purchases and sales. Your answer must include a visualization to demonstrate the relationship.**

# %% [markdown]
# Finally, we want to combine the two pieces of information to see how the purchases impact sales. So far pet stores with over 1000 sales would be ideal, there’s need to look at the two variables together to see if this is realistic.
#
# ![t4a](t4a.png)
#
# When looking at just the sales, we excluded a single outlying value so that we could see the majority of the data. To show the impact, we can look at the range of number of sales by purchase with this outlier in the data. In the graphic above, you can see that this outlier is dominating the data and making comparison difficult. To make it easier to compare the rest of the data, we will remove this outlier.
#
# ![t4b](t4b.png)
#
# After we removed the outliers, we can focus on the main range of data. Although pet purchases include the sales with the highest kind of purchases, the interquartile range of the sales on one-off purchases (0) is lower than that of the repeated purchases (1). This would suggest that the majority of the number of sales may be higher if customers make repeated purchases. However, this could also be an effect of having the largest number of repeated purchase, so the large number of repeated purchase can bring the median low.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
